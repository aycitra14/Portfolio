# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)
sns.set_context('notebook')
sns.set_style('whitegrid')
sns.set_palette('Spectral')

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('customer_data.csv')
df.head()
# Out:
#                  name  age  gender    education  income   country
# 0  Teresa Williams MD   42  Female  High School   53936  Slovenia  \
# 1     Christine Myers   49  Female       Master   82468     Aruba
# 2       Dwayne Moreno   55    Male     Bachelor   56941    Cyprus
# 3          Amy Norton   24  Female     Bachelor   60651     Palau
# 4         Tonya Adams   64    Male       Master   81884    Zambia
#
#    purchase_frequency   spending
# 0                 0.9  13227.120
# 1                 0.6  12674.040
# 2                 0.3   5354.115
# 3                 0.2   2606.510
# 4                 0.9  18984.780

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   name                1000 non-null   object
#  1   age                 1000 non-null   int64
#  2   gender              1000 non-null   object
#  3   education           1000 non-null   object
#  4   income              1000 non-null   int64
#  5   country             1000 non-null   object
#  6   purchase_frequency  1000 non-null   float64
#  7   spending            1000 non-null   float64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 62.6+ KB

# %%
df['spending'] = df['spending'].astype('int64')

# %%
df.head()
# Out:
#                  name  age  gender    education  income   country
# 0  Teresa Williams MD   42  Female  High School   53936  Slovenia  \
# 1     Christine Myers   49  Female       Master   82468     Aruba
# 2       Dwayne Moreno   55    Male     Bachelor   56941    Cyprus
# 3          Amy Norton   24  Female     Bachelor   60651     Palau
# 4         Tonya Adams   64    Male       Master   81884    Zambia
#
#    purchase_frequency  spending
# 0                 0.9     13227
# 1                 0.6     12674
# 2                 0.3      5354
# 3                 0.2      2606
# 4                 0.9     18984

# %%
df.columns = df.columns.str.replace(' ', '')

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# name                  0
# age                   0
# gender                0
# education             0
# income                0
# country               0
# purchase_frequency    0
# spending              0
# dtype: int64

# %%
sns.distplot(df['income'], kde=False, hist=True)
# Out:
# <Axes: xlabel='income'>

# %%
df.to_csv('customer data_cleaned.csv',index=False)

# %%
print(df.tail)
# Out:
# <bound method NDFrame.tail of                    name  age  gender    education  income
# 0    Teresa Williams MD   42  Female  High School   53936  \
# 1       Christine Myers   49  Female       Master   82468
# 2         Dwayne Moreno   55    Male     Bachelor   56941
# 3            Amy Norton   24  Female     Bachelor   60651
# 4           Tonya Adams   64    Male       Master   81884
# ..                  ...  ...     ...          ...     ...
# 995          Jason Haas   42  Female          PhD   98170
# 996       Sharon Valdez   39    Male  High School   59174
# 997       Andrew Taylor   50    Male       Master   59808
# 998     Jessica Johnson   50  Female       Master   58272
# 999      Brian Williams   38  Female     Bachelor   32512
#
#                     country  purchase_frequency  spending
# 0                  Slovenia                 0.9     13227
# 1                     Aruba                 0.6     12674
# 2                    Cyprus                 0.3      5354
# ...

# %%
print(df['income'].corr(df['purchase_frequency']))
#your income is not that relate to purchase frequency
# Out:
# 0.028186734113904578

# %%
print(df['income'].corr(df['spending']))
# Out:
# 0.12285125212120547

# %%
print(df['spending'].corr(df['purchase_frequency']))
#the more you spend, the more your purchase frequency
# Out:
# 0.895160742079893

# %%
df.describe(include='all')
# Out:
#                  name          age gender education        income country
# count            1000  1000.000000   1000      1000   1000.000000    1000  \
# unique            991          NaN      2         4           NaN     239
# top     Michael Brown          NaN   Male  Bachelor           NaN   Congo
# freq                3          NaN    501       271           NaN      12
# mean              NaN    41.754000    NaN       NaN  59277.852000     NaN
# std               NaN    13.778582    NaN       NaN  23258.377128     NaN
# min               NaN    18.000000    NaN       NaN  20031.000000     NaN
# 25%               NaN    30.000000    NaN       NaN  38825.500000     NaN
# 50%               NaN    42.000000    NaN       NaN  58972.000000     NaN
# 75%               NaN    54.000000    NaN       NaN  79114.000000     NaN
# max               NaN    65.000000    NaN       NaN  99780.000000     NaN
#
#         purchase_frequency      spending
# ...

# %%
df.hist(figsize=(20,30))
# Out:
# array([[<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'income'}>],
#        [<Axes: title={'center': 'purchase_frequency'}>,
#         <Axes: title={'center': 'spending'}>]], dtype=object)

# %%
sns.boxplot(x='education',y='spending', data=df)
#means the higher your education, most likely your spending will be much more
# Out:
# <Axes: xlabel='education', ylabel='spending'>

# %%
sns.boxplot(x='gender',y='spending', data=df)
#means female tend to spend more
# Out:
# <Axes: xlabel='gender', ylabel='spending'>

# %%
sns.boxplot(x='gender',y='income', data=df)
#means male earn more than women
# Out:
# <Axes: xlabel='gender', ylabel='income'>

# %%
sns.boxplot(x='education',y='purchase_frequency', data=df)
# Out:
# <Axes: xlabel='education', ylabel='purchase_frequency'>
